# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'Name': ['Product A', 'Product B', 'Product C', 'Product D', 'Product E'],
    'Stock': [120, 80, 150, 60, 200]
})
df = pd.read_csv("products.csv")

# %%
df
# Out:
#     Index                                   Name  \
# 0       1   Compact Printer Air Advanced Digital
# 1       2                                 Tablet
# 2       3                   Smart Blender Cooker
# 3       4           Advanced Router Rechargeable
# 4       5           Portable Mouse Monitor Phone
# ..    ...                                    ...
# 95     96                                 Router
# 96     97     Fast Thermostat Microphone Scooter
# 97     98  Eco Heater Toaster Stove Silent Sense
# 98     99               Clean Blender Scale Lite
# 99    100                             Smart Lamp
#
#                                           Description  \
# 0       Situation organization these memory much off.
# 1         Discussion loss politics free one thousand.
# 2                                   No situation per.
# 3                     For force gas energy six laugh.
# 4   Feeling back religious however author room sci...
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt


plt.plot(df['Name'], df['Stock'], marker='o', linestyle='-', color='blue')
plt.xlabel('Product Name')
plt.ylabel('Stock Quantity')
plt.title('Line Chart of Product Stock')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


plt.bar(df['Name'], df['Stock'], color='green')
plt.xlabel('Product Name')
plt.ylabel('Stock Quantity')
plt.title('Bar Chart of Product Stock')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


plt.scatter(df['Name'], df['Stock'], color='red')
plt.xlabel('Product Name')
plt.ylabel('Stock Quantity')
plt.title('Scatter Plot of Product Stock')
plt.show()
